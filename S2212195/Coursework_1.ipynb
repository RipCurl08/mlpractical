# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the MLP2024_25_CW1_Spec.pdf (see Learn,  Assignment Submission, Coursework 1). The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for num_epochs epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    ax_1.set_ylabel('Error')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    ax_2.set_xlabel('Accuracy')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
import sys
import os 
if os.name == 'nt':
    os.environ['MLP_DATA_DIR'] = 'C:\\Schoolwork\\4\\MLP\\mlpractical\\data'
    sys.path.append('C:\\Schoolwork\\4\\MLP')
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider

# Seed a random number generator
seed = 11102019 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
# Out:
# KeysView(NpzFile 'C:\\Schoolwork\\4\\MLP\\mlpractical\\data\\emnist-train.npz' with keys: inputs, targets)
# KeysView(NpzFile 'C:\\Schoolwork\\4\\MLP\\mlpractical\\data\\emnist-valid.npz' with keys: inputs, targets)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# %pip install tqdm

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 32

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

# Create model with ONE hidden layer
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
def train_models(
        models, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Run the optimiser for num_epochs epochs (full passes through the training set)
    # printing statistics every epoch.
    statss = []
    keyss = []
    run_times = []
    for model in models:
        optimiser = Optimiser(
            model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)
        stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)
        statss.append(stats)
        keyss.append(keys)
        run_times.append(run_time)
    
    return statss, keyss, run_times

# %%
# Train width models

learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 32

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model0 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

hidden_dim = 64

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model1 = MultipleLayerModel([
    AffineLayer(input_dim, 64, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(64, output_dim, weights_init, biases_init) # output layer
])

hidden_dim = 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model2 = MultipleLayerModel([
    AffineLayer(input_dim, 128, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(128, output_dim, weights_init, biases_init) # output layer
])

models = [model0,model1,model2]

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
statss, keyss, run_times= train_models(
    models, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
def plot_stats(num_models,statss,keyss,plot_name,labels):
    colors = ['r','b','g']
    colors = colors[:num_models]

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for i in range(0,num_models):
        for k in ['error(train)', 'error(valid)']:
            if k == 'error(valid)':
                ax_1.plot(np.arange(1, statss[i].shape[0]) * stats_interval, 
                        statss[i][1:, keyss[i][k]], color=colors[i], label=str(labels[i]+' '+k), linestyle='dashed')
            else:
                ax_1.plot(np.arange(1, statss[i].shape[0]) * stats_interval, 
                        statss[i][1:, keyss[i][k]], color=colors[i], label=str(labels[i]+' '+k))
    ax_1.legend(loc=2)
    ax_1.set_xlabel('Epoch number')
    ax_1.set_ylabel('Error')
    ax_1.grid('on')
    fig_1.tight_layout()
    fig_1.savefig('error_curve_' + plot_name +'.pdf')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for i in range(0,num_models):
        for k in ['acc(train)', 'acc(valid)']:
            if k == 'acc(valid)':
                ax_2.plot(np.arange(1, statss[i].shape[0]) * stats_interval, 
                        statss[i][1:, keyss[i][k]], color=colors[i],label=str(labels[i]+' '+k), linestyle='dashed')
            else:
                ax_2.plot(np.arange(1, statss[i].shape[0]) * stats_interval, 
                        statss[i][1:, keyss[i][k]], color=colors[i],label=str(labels[i]+' '+k))
    ax_2.legend(loc=2)
    ax_2.set_xlabel('Epoch number')
    ax_2.set_xlabel('Accuracy')
    ax_2.grid('on')
    fig_2.tight_layout()
    fig_2.savefig('acc_curve_' + plot_name +'.pdf')

    return fig_1, ax_1, fig_2, ax_2

# %%
def print_stats(number,stats,keys):
    for i in range(0,number):
        print('Val acc: ' + str(stats[i][-1, keys[i]['acc(valid)']]) + ', Train Error: ' + str(stats[i][-1, keys[i]['error(train)']]) + ', Val Error: ' + str(stats[i][-1, keys[i]['error(valid)']]))

# %%
_ = plot_stats(3,statss,keyss,'width',['height 32','height 64','height 128'])
print_stats(3,statss,keyss)

# %%
# Create model with TWO hidden layers
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # first hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # second hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
# Train depth models

learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model0 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model1 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model2 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

models = [model0,model1,model2]

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

statss, keyss, run_times= train_models(
    models, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
_ = plot_stats(3,statss,keyss,'depth',['depth 1','depth 2','depth 3'])
print_stats(3,statss,keyss)

# %%
# Baseline model

# Load smoothed labels
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng,smooth_labels=True)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng,smooth_labels=True)

learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
learning_rule = AdamLearningRule(learning_rate=learning_rate)

statss, keyss, run_times= train_models(
    [model], error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)

# %%
#_ = plot_stats(1,statss,keyss,'baseline',[''])
print_stats(1,statss,keyss)

# %%
# Dropout model

from mlp.layers import DropoutLayer

learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    DropoutLayer(incl_prob=0.7),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
learning_rule = AdamLearningRule(learning_rate=learning_rate)

statss, keyss, run_times= train_models(
    [model], error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
print_stats(1,statss,keyss)

# %%
# L1 model

from mlp.penalties import L1Penalty

learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init,weights_penalty=L1Penalty(1e-3),biases_penalty=L1Penalty(1e-3)),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=L1Penalty(1e-3),biases_penalty=L1Penalty(1e-3)),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=L1Penalty(1e-3),biases_penalty=L1Penalty(1e-3)),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init,weights_penalty=L1Penalty(1e-3),biases_penalty=L1Penalty(1e-3))
])

error = CrossEntropySoftmaxError()
learning_rule = AdamLearningRule(learning_rate=learning_rate)

statss, keyss, run_times= train_models(
    [model], error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 11.2s to complete
#     error(train)=1.32e+00, acc(train)=6.26e-01, error(valid)=1.33e+00, acc(valid)=6.23e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 10.3s to complete
#     error(train)=1.18e+00, acc(train)=6.62e-01, error(valid)=1.19e+00, acc(valid)=6.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 9.6s to complete
#     error(train)=1.08e+00, acc(train)=6.85e-01, error(valid)=1.09e+00, acc(valid)=6.83e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 9.3s to complete
#     error(train)=1.04e+00, acc(train)=6.90e-01, error(valid)=1.04e+00, acc(valid)=6.87e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 12.3s to complete
#     error(train)=1.01e+00, acc(train)=7.04e-01, error(valid)=1.01e+00, acc(valid)=6.99e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 9.1s to complete
#     error(train)=9.73e-01, acc(train)=7.15e-01, error(valid)=9.82e-01, acc(valid)=7.13e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 7: 10.0s to complete
#     error(train)=9.42e-01, acc(train)=7.22e-01, error(valid)=9.48e-01, acc(valid)=7.21e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 8: 8.0s to complete
#     error(train)=9.40e-01, acc(train)=7.22e-01, error(valid)=9.48e-01, acc(valid)=7.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 9: 8.5s to complete
#     error(train)=9.39e-01, acc(train)=7.23e-01, error(valid)=9.43e-01, acc(valid)=7.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 10: 7.7s to complete
#     error(train)=9.01e-01, acc(train)=7.32e-01, error(valid)=9.08e-01, acc(valid)=7.33e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 11: 12.0s to complete
#     error(train)=8.81e-01, acc(train)=7.40e-01, error(valid)=8.91e-01, acc(valid)=7.36e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 12: 11.4s to complete
#     error(train)=8.68e-01, acc(train)=7.43e-01, error(valid)=8.80e-01, acc(valid)=7.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 13: 12.0s to complete
#     error(train)=8.67e-01, acc(train)=7.43e-01, error(valid)=8.79e-01, acc(valid)=7.38e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 14: 13.8s to complete
#     error(train)=8.53e-01, acc(train)=7.44e-01, error(valid)=8.64e-01, acc(valid)=7.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 15: 13.3s to complete
#     error(train)=8.47e-01, acc(train)=7.44e-01, error(valid)=8.55e-01, acc(valid)=7.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 16: 11.8s to complete
#     error(train)=8.45e-01, acc(train)=7.47e-01, error(valid)=8.57e-01, acc(valid)=7.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 17: 12.1s to complete
#     error(train)=8.31e-01, acc(train)=7.50e-01, error(valid)=8.44e-01, acc(valid)=7.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 18: 11.7s to complete
#     error(train)=8.23e-01, acc(train)=7.52e-01, error(valid)=8.33e-01, acc(valid)=7.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 19: 14.4s to complete
#     error(train)=8.24e-01, acc(train)=7.53e-01, error(valid)=8.39e-01, acc(valid)=7.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 20: 11.7s to complete
#     error(train)=8.32e-01, acc(train)=7.48e-01, error(valid)=8.47e-01, acc(valid)=7.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 21: 12.6s to complete
#     error(train)=8.16e-01, acc(train)=7.55e-01, error(valid)=8.31e-01, acc(valid)=7.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 22: 17.7s to complete
#     error(train)=8.11e-01, acc(train)=7.54e-01, error(valid)=8.27e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 23: 11.1s to complete
#     error(train)=8.13e-01, acc(train)=7.53e-01, error(valid)=8.26e-01, acc(valid)=7.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 24: 10.9s to complete
#     error(train)=8.12e-01, acc(train)=7.53e-01, error(valid)=8.25e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 25: 11.1s to complete
#     error(train)=8.20e-01, acc(train)=7.53e-01, error(valid)=8.31e-01, acc(valid)=7.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 26: 11.7s to complete
#     error(train)=8.11e-01, acc(train)=7.53e-01, error(valid)=8.26e-01, acc(valid)=7.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 27: 14.3s to complete
#     error(train)=8.47e-01, acc(train)=7.42e-01, error(valid)=8.63e-01, acc(valid)=7.39e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 28: 15.0s to complete
#     error(train)=8.22e-01, acc(train)=7.49e-01, error(valid)=8.35e-01, acc(valid)=7.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 29: 14.6s to complete
#     error(train)=8.14e-01, acc(train)=7.49e-01, error(valid)=8.27e-01, acc(valid)=7.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 30: 17.5s to complete
#     error(train)=8.24e-01, acc(train)=7.48e-01, error(valid)=8.41e-01, acc(valid)=7.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 31: 14.8s to complete
#     error(train)=7.93e-01, acc(train)=7.58e-01, error(valid)=8.09e-01, acc(valid)=7.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 32: 14.0s to complete
#     error(train)=8.15e-01, acc(train)=7.51e-01, error(valid)=8.26e-01, acc(valid)=7.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 33: 13.1s to complete
#     error(train)=8.06e-01, acc(train)=7.53e-01, error(valid)=8.20e-01, acc(valid)=7.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 34: 15.5s to complete
#     error(train)=8.03e-01, acc(train)=7.55e-01, error(valid)=8.19e-01, acc(valid)=7.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 35: 13.7s to complete
#     error(train)=8.11e-01, acc(train)=7.52e-01, error(valid)=8.26e-01, acc(valid)=7.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 36: 17.3s to complete
#     error(train)=8.04e-01, acc(train)=7.53e-01, error(valid)=8.21e-01, acc(valid)=7.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 37: 16.9s to complete
#     error(train)=7.92e-01, acc(train)=7.58e-01, error(valid)=8.07e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 38: 18.5s to complete
#     error(train)=8.40e-01, acc(train)=7.40e-01, error(valid)=8.54e-01, acc(valid)=7.39e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 39: 12.5s to complete
#     error(train)=8.07e-01, acc(train)=7.53e-01, error(valid)=8.24e-01, acc(valid)=7.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 40: 16.6s to complete
#     error(train)=8.01e-01, acc(train)=7.56e-01, error(valid)=8.12e-01, acc(valid)=7.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 41: 15.6s to complete
#     error(train)=7.90e-01, acc(train)=7.59e-01, error(valid)=8.06e-01, acc(valid)=7.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 42: 20.0s to complete
#     error(train)=7.85e-01, acc(train)=7.60e-01, error(valid)=7.97e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 43: 16.3s to complete
#     error(train)=7.92e-01, acc(train)=7.57e-01, error(valid)=8.07e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 44: 15.8s to complete
#     error(train)=8.06e-01, acc(train)=7.54e-01, error(valid)=8.20e-01, acc(valid)=7.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 45: 12.4s to complete
#     error(train)=7.72e-01, acc(train)=7.63e-01, error(valid)=7.86e-01, acc(valid)=7.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 46: 11.1s to complete
#     error(train)=7.84e-01, acc(train)=7.59e-01, error(valid)=7.99e-01, acc(valid)=7.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 47: 13.7s to complete
#     error(train)=7.84e-01, acc(train)=7.60e-01, error(valid)=8.00e-01, acc(valid)=7.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 48: 13.3s to complete
#     error(train)=7.86e-01, acc(train)=7.60e-01, error(valid)=8.01e-01, acc(valid)=7.58e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 49: 11.4s to complete
#     error(train)=8.03e-01, acc(train)=7.51e-01, error(valid)=8.19e-01, acc(valid)=7.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 50: 13.8s to complete
#     error(train)=7.93e-01, acc(train)=7.55e-01, error(valid)=8.10e-01, acc(valid)=7.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 51: 14.0s to complete
#     error(train)=7.92e-01, acc(train)=7.56e-01, error(valid)=8.04e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 52: 16.7s to complete
#     error(train)=7.77e-01, acc(train)=7.62e-01, error(valid)=7.99e-01, acc(valid)=7.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 53: 15.5s to complete
#     error(train)=7.77e-01, acc(train)=7.62e-01, error(valid)=7.96e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 54: 13.5s to complete
#     error(train)=7.88e-01, acc(train)=7.60e-01, error(valid)=8.04e-01, acc(valid)=7.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 55: 15.2s to complete
#     error(train)=7.92e-01, acc(train)=7.58e-01, error(valid)=8.06e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 56: 12.4s to complete
#     error(train)=8.10e-01, acc(train)=7.52e-01, error(valid)=8.19e-01, acc(valid)=7.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 57: 15.1s to complete
#     error(train)=7.97e-01, acc(train)=7.54e-01, error(valid)=8.16e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 58: 16.8s to complete
#     error(train)=7.86e-01, acc(train)=7.58e-01, error(valid)=8.06e-01, acc(valid)=7.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 59: 27.3s to complete
#     error(train)=7.89e-01, acc(train)=7.57e-01, error(valid)=8.04e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 60: 10.8s to complete
#     error(train)=7.75e-01, acc(train)=7.65e-01, error(valid)=7.92e-01, acc(valid)=7.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 61: 15.1s to complete
#     error(train)=7.93e-01, acc(train)=7.57e-01, error(valid)=8.10e-01, acc(valid)=7.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 62: 16.9s to complete
#     error(train)=7.85e-01, acc(train)=7.62e-01, error(valid)=8.03e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 63: 9.6s to complete
#     error(train)=7.73e-01, acc(train)=7.62e-01, error(valid)=7.97e-01, acc(valid)=7.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 64: 12.5s to complete
#     error(train)=7.72e-01, acc(train)=7.63e-01, error(valid)=7.92e-01, acc(valid)=7.58e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 65: 12.6s to complete
#     error(train)=7.73e-01, acc(train)=7.63e-01, error(valid)=7.92e-01, acc(valid)=7.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 66: 15.7s to complete
#     error(train)=7.92e-01, acc(train)=7.56e-01, error(valid)=8.19e-01, acc(valid)=7.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 67: 19.7s to complete
#     error(train)=7.98e-01, acc(train)=7.54e-01, error(valid)=8.20e-01, acc(valid)=7.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 68: 18.8s to complete
#     error(train)=7.83e-01, acc(train)=7.58e-01, error(valid)=8.02e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 69: 18.7s to complete
#     error(train)=7.67e-01, acc(train)=7.64e-01, error(valid)=7.87e-01, acc(valid)=7.57e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 70: 15.8s to complete
#     error(train)=7.76e-01, acc(train)=7.62e-01, error(valid)=7.97e-01, acc(valid)=7.58e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 71: 16.2s to complete
#     error(train)=7.66e-01, acc(train)=7.64e-01, error(valid)=7.88e-01, acc(valid)=7.57e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 72: 16.3s to complete
#     error(train)=7.74e-01, acc(train)=7.61e-01, error(valid)=7.95e-01, acc(valid)=7.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 73: 12.8s to complete
#     error(train)=7.76e-01, acc(train)=7.62e-01, error(valid)=7.95e-01, acc(valid)=7.58e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 74: 12.1s to complete
#     error(train)=7.82e-01, acc(train)=7.57e-01, error(valid)=8.06e-01, acc(valid)=7.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 75: 10.9s to complete
#     error(train)=7.65e-01, acc(train)=7.66e-01, error(valid)=7.82e-01, acc(valid)=7.61e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 76: 10.6s to complete
#     error(train)=7.74e-01, acc(train)=7.60e-01, error(valid)=7.92e-01, acc(valid)=7.61e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 77: 14.4s to complete
#     error(train)=7.62e-01, acc(train)=7.63e-01, error(valid)=7.85e-01, acc(valid)=7.60e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 78: 10.1s to complete
#     error(train)=7.82e-01, acc(train)=7.60e-01, error(valid)=8.00e-01, acc(valid)=7.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 79: 12.1s to complete
#     error(train)=7.63e-01, acc(train)=7.66e-01, error(valid)=7.87e-01, acc(valid)=7.62e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 80: 10.7s to complete
#     error(train)=7.78e-01, acc(train)=7.57e-01, error(valid)=7.98e-01, acc(valid)=7.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 81: 10.3s to complete
#     error(train)=7.65e-01, acc(train)=7.65e-01, error(valid)=7.86e-01, acc(valid)=7.62e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 82: 12.5s to complete
#     error(train)=7.69e-01, acc(train)=7.62e-01, error(valid)=7.92e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 83: 13.9s to complete
#     error(train)=7.74e-01, acc(train)=7.61e-01, error(valid)=7.92e-01, acc(valid)=7.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 84: 9.1s to complete
#     error(train)=7.63e-01, acc(train)=7.64e-01, error(valid)=7.85e-01, acc(valid)=7.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 85: 10.7s to complete
#     error(train)=7.69e-01, acc(train)=7.63e-01, error(valid)=7.88e-01, acc(valid)=7.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 86: 11.5s to complete
#     error(train)=7.72e-01, acc(train)=7.61e-01, error(valid)=7.94e-01, acc(valid)=7.58e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 87: 11.6s to complete
#     error(train)=7.62e-01, acc(train)=7.67e-01, error(valid)=7.84e-01, acc(valid)=7.60e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 88: 11.8s to complete
#     error(train)=7.64e-01, acc(train)=7.64e-01, error(valid)=7.87e-01, acc(valid)=7.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 89: 9.5s to complete
#     error(train)=7.58e-01, acc(train)=7.68e-01, error(valid)=7.78e-01, acc(valid)=7.60e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 90: 11.0s to complete
#     error(train)=7.52e-01, acc(train)=7.69e-01, error(valid)=7.77e-01, acc(valid)=7.61e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 91: 10.6s to complete
#     error(train)=7.50e-01, acc(train)=7.69e-01, error(valid)=7.72e-01, acc(valid)=7.63e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 92: 8.1s to complete
#     error(train)=7.62e-01, acc(train)=7.65e-01, error(valid)=7.85e-01, acc(valid)=7.61e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 93: 9.6s to complete
#     error(train)=7.49e-01, acc(train)=7.69e-01, error(valid)=7.70e-01, acc(valid)=7.63e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 94: 9.8s to complete
#     error(train)=7.50e-01, acc(train)=7.65e-01, error(valid)=7.70e-01, acc(valid)=7.61e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 95: 9.8s to complete
#     error(train)=7.64e-01, acc(train)=7.66e-01, error(valid)=7.92e-01, acc(valid)=7.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 96: 10.3s to complete
#     error(train)=7.53e-01, acc(train)=7.67e-01, error(valid)=7.75e-01, acc(valid)=7.66e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 97: 10.1s to complete
#     error(train)=7.65e-01, acc(train)=7.64e-01, error(valid)=7.90e-01, acc(valid)=7.58e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 98: 9.7s to complete
#     error(train)=7.46e-01, acc(train)=7.69e-01, error(valid)=7.68e-01, acc(valid)=7.62e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 99: 9.7s to complete
#     error(train)=7.46e-01, acc(train)=7.71e-01, error(valid)=7.71e-01, acc(valid)=7.67e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 100: 9.2s to complete
#     error(train)=7.55e-01, acc(train)=7.68e-01, error(valid)=7.77e-01, acc(valid)=7.64e-01

# %%
print_stats(1,statss,keyss)
# Out:
# Val acc: 0.7636075949367088, Train Error: 0.7552094438596266, Val Error: 0.7765874761297045

# %%
# L2 model

from mlp.penalties import L2Penalty

learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init,weights_penalty=L2Penalty(1e-3),biases_penalty=L2Penalty(1e-3)),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=L2Penalty(1e-3),biases_penalty=L2Penalty(1e-3)),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=L2Penalty(1e-3),biases_penalty=L2Penalty(1e-3)),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init,weights_penalty=L2Penalty(1e-3),biases_penalty=L2Penalty(1e-3))
])

error = CrossEntropySoftmaxError()
learning_rule = AdamLearningRule(learning_rate=learning_rate)

statss, keyss, run_times= train_models(
    [model], error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.2s to complete
#     error(train)=7.59e-01, acc(train)=7.61e-01, error(valid)=7.85e-01, acc(valid)=7.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.1s to complete
#     error(train)=5.84e-01, acc(train)=8.15e-01, error(valid)=6.12e-01, acc(valid)=8.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.0s to complete
#     error(train)=5.33e-01, acc(train)=8.25e-01, error(valid)=5.75e-01, acc(valid)=8.11e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.1s to complete
#     error(train)=5.23e-01, acc(train)=8.25e-01, error(valid)=5.67e-01, acc(valid)=8.12e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.1s to complete
#     error(train)=4.78e-01, acc(train)=8.40e-01, error(valid)=5.25e-01, acc(valid)=8.29e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.0s to complete
#     error(train)=4.56e-01, acc(train)=8.48e-01, error(valid)=5.03e-01, acc(valid)=8.34e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 7: 3.3s to complete
#     error(train)=4.66e-01, acc(train)=8.42e-01, error(valid)=5.17e-01, acc(valid)=8.28e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 8: 3.3s to complete
#     error(train)=4.39e-01, acc(train)=8.51e-01, error(valid)=4.94e-01, acc(valid)=8.36e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 9: 3.1s to complete
#     error(train)=4.44e-01, acc(train)=8.50e-01, error(valid)=4.98e-01, acc(valid)=8.33e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 10: 3.0s to complete
#     error(train)=4.38e-01, acc(train)=8.49e-01, error(valid)=4.94e-01, acc(valid)=8.32e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 11: 3.0s to complete
#     error(train)=4.09e-01, acc(train)=8.59e-01, error(valid)=4.60e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 12: 3.1s to complete
#     error(train)=4.20e-01, acc(train)=8.56e-01, error(valid)=4.72e-01, acc(valid)=8.40e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 13: 3.1s to complete
#     error(train)=4.17e-01, acc(train)=8.57e-01, error(valid)=4.77e-01, acc(valid)=8.40e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 14: 3.1s to complete
#     error(train)=4.16e-01, acc(train)=8.56e-01, error(valid)=4.74e-01, acc(valid)=8.39e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 15: 3.1s to complete
#     error(train)=4.24e-01, acc(train)=8.52e-01, error(valid)=4.84e-01, acc(valid)=8.33e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 16: 3.1s to complete
#     error(train)=4.22e-01, acc(train)=8.56e-01, error(valid)=4.80e-01, acc(valid)=8.40e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 17: 3.2s to complete
#     error(train)=4.08e-01, acc(train)=8.60e-01, error(valid)=4.68e-01, acc(valid)=8.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 18: 3.2s to complete
#     error(train)=4.01e-01, acc(train)=8.61e-01, error(valid)=4.60e-01, acc(valid)=8.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 19: 3.1s to complete
#     error(train)=3.97e-01, acc(train)=8.64e-01, error(valid)=4.51e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 20: 3.1s to complete
#     error(train)=4.00e-01, acc(train)=8.61e-01, error(valid)=4.56e-01, acc(valid)=8.43e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 21: 3.0s to complete
#     error(train)=3.98e-01, acc(train)=8.64e-01, error(valid)=4.58e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 22: 3.2s to complete
#     error(train)=3.93e-01, acc(train)=8.66e-01, error(valid)=4.52e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 23: 3.2s to complete
#     error(train)=3.79e-01, acc(train)=8.67e-01, error(valid)=4.38e-01, acc(valid)=8.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 24: 3.2s to complete
#     error(train)=3.96e-01, acc(train)=8.64e-01, error(valid)=4.52e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 25: 3.1s to complete
#     error(train)=3.94e-01, acc(train)=8.65e-01, error(valid)=4.54e-01, acc(valid)=8.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 26: 3.1s to complete
#     error(train)=3.82e-01, acc(train)=8.69e-01, error(valid)=4.42e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 27: 3.1s to complete
#     error(train)=3.82e-01, acc(train)=8.68e-01, error(valid)=4.35e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 28: 3.4s to complete
#     error(train)=3.90e-01, acc(train)=8.66e-01, error(valid)=4.45e-01, acc(valid)=8.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 29: 3.2s to complete
#     error(train)=3.97e-01, acc(train)=8.62e-01, error(valid)=4.56e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 30: 3.1s to complete
#     error(train)=3.94e-01, acc(train)=8.64e-01, error(valid)=4.47e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 31: 3.1s to complete
#     error(train)=3.85e-01, acc(train)=8.67e-01, error(valid)=4.42e-01, acc(valid)=8.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 32: 3.2s to complete
#     error(train)=3.92e-01, acc(train)=8.64e-01, error(valid)=4.51e-01, acc(valid)=8.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 33: 3.2s to complete
#     error(train)=3.77e-01, acc(train)=8.70e-01, error(valid)=4.36e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 34: 3.2s to complete
#     error(train)=3.80e-01, acc(train)=8.69e-01, error(valid)=4.35e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 35: 3.2s to complete
#     error(train)=3.91e-01, acc(train)=8.63e-01, error(valid)=4.49e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 36: 3.1s to complete
#     error(train)=3.82e-01, acc(train)=8.69e-01, error(valid)=4.37e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 37: 3.0s to complete
#     error(train)=3.75e-01, acc(train)=8.70e-01, error(valid)=4.34e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 38: 3.3s to complete
#     error(train)=3.75e-01, acc(train)=8.70e-01, error(valid)=4.33e-01, acc(valid)=8.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 39: 3.2s to complete
#     error(train)=4.00e-01, acc(train)=8.61e-01, error(valid)=4.60e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 40: 3.1s to complete
#     error(train)=3.92e-01, acc(train)=8.59e-01, error(valid)=4.58e-01, acc(valid)=8.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 41: 3.2s to complete
#     error(train)=3.81e-01, acc(train)=8.68e-01, error(valid)=4.42e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 42: 3.1s to complete
#     error(train)=3.82e-01, acc(train)=8.67e-01, error(valid)=4.44e-01, acc(valid)=8.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 43: 3.2s to complete
#     error(train)=4.08e-01, acc(train)=8.59e-01, error(valid)=4.75e-01, acc(valid)=8.36e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 44: 3.1s to complete
#     error(train)=3.72e-01, acc(train)=8.71e-01, error(valid)=4.34e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 45: 3.3s to complete
#     error(train)=3.65e-01, acc(train)=8.74e-01, error(valid)=4.22e-01, acc(valid)=8.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 46: 3.1s to complete
#     error(train)=3.66e-01, acc(train)=8.72e-01, error(valid)=4.28e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 47: 3.2s to complete
#     error(train)=3.80e-01, acc(train)=8.69e-01, error(valid)=4.37e-01, acc(valid)=8.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 48: 3.3s to complete
#     error(train)=3.77e-01, acc(train)=8.67e-01, error(valid)=4.42e-01, acc(valid)=8.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 49: 3.2s to complete
#     error(train)=3.71e-01, acc(train)=8.70e-01, error(valid)=4.34e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 50: 3.3s to complete
#     error(train)=3.85e-01, acc(train)=8.67e-01, error(valid)=4.45e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 51: 3.2s to complete
#     error(train)=3.77e-01, acc(train)=8.70e-01, error(valid)=4.39e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 52: 3.2s to complete
#     error(train)=3.75e-01, acc(train)=8.70e-01, error(valid)=4.37e-01, acc(valid)=8.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 53: 3.2s to complete
#     error(train)=3.69e-01, acc(train)=8.72e-01, error(valid)=4.34e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 54: 3.3s to complete
#     error(train)=3.78e-01, acc(train)=8.68e-01, error(valid)=4.37e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 55: 3.2s to complete
#     error(train)=3.69e-01, acc(train)=8.71e-01, error(valid)=4.30e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 56: 3.2s to complete
#     error(train)=3.70e-01, acc(train)=8.71e-01, error(valid)=4.33e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 57: 3.2s to complete
#     error(train)=3.62e-01, acc(train)=8.74e-01, error(valid)=4.22e-01, acc(valid)=8.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 58: 3.2s to complete
#     error(train)=3.83e-01, acc(train)=8.66e-01, error(valid)=4.49e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 59: 3.2s to complete
#     error(train)=3.75e-01, acc(train)=8.69e-01, error(valid)=4.42e-01, acc(valid)=8.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 60: 3.1s to complete
#     error(train)=3.67e-01, acc(train)=8.73e-01, error(valid)=4.26e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 61: 3.1s to complete
#     error(train)=3.89e-01, acc(train)=8.63e-01, error(valid)=4.49e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 62: 3.2s to complete
#     error(train)=3.65e-01, acc(train)=8.73e-01, error(valid)=4.28e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 63: 3.3s to complete
#     error(train)=3.64e-01, acc(train)=8.73e-01, error(valid)=4.26e-01, acc(valid)=8.57e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 64: 3.2s to complete
#     error(train)=3.69e-01, acc(train)=8.69e-01, error(valid)=4.32e-01, acc(valid)=8.50e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 65: 3.3s to complete
#     error(train)=3.68e-01, acc(train)=8.71e-01, error(valid)=4.31e-01, acc(valid)=8.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 66: 3.1s to complete
#     error(train)=3.68e-01, acc(train)=8.73e-01, error(valid)=4.30e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 67: 3.2s to complete
#     error(train)=3.59e-01, acc(train)=8.74e-01, error(valid)=4.23e-01, acc(valid)=8.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 68: 3.3s to complete
#     error(train)=3.74e-01, acc(train)=8.71e-01, error(valid)=4.36e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 69: 3.3s to complete
#     error(train)=3.66e-01, acc(train)=8.74e-01, error(valid)=4.30e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 70: 3.1s to complete
#     error(train)=3.72e-01, acc(train)=8.73e-01, error(valid)=4.35e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 71: 3.2s to complete
#     error(train)=3.71e-01, acc(train)=8.72e-01, error(valid)=4.35e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 72: 3.3s to complete
#     error(train)=3.62e-01, acc(train)=8.74e-01, error(valid)=4.28e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 73: 3.1s to complete
#     error(train)=3.71e-01, acc(train)=8.70e-01, error(valid)=4.35e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 74: 3.2s to complete
#     error(train)=3.66e-01, acc(train)=8.72e-01, error(valid)=4.26e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 75: 3.3s to complete
#     error(train)=3.76e-01, acc(train)=8.69e-01, error(valid)=4.39e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 76: 3.5s to complete
#     error(train)=3.72e-01, acc(train)=8.71e-01, error(valid)=4.38e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 77: 3.3s to complete
#     error(train)=3.72e-01, acc(train)=8.71e-01, error(valid)=4.32e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 78: 3.3s to complete
#     error(train)=3.58e-01, acc(train)=8.75e-01, error(valid)=4.23e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 79: 3.3s to complete
#     error(train)=3.59e-01, acc(train)=8.75e-01, error(valid)=4.23e-01, acc(valid)=8.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 80: 3.2s to complete
#     error(train)=3.69e-01, acc(train)=8.71e-01, error(valid)=4.31e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 81: 3.3s to complete
#     error(train)=3.65e-01, acc(train)=8.73e-01, error(valid)=4.28e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 82: 3.2s to complete
#     error(train)=3.61e-01, acc(train)=8.75e-01, error(valid)=4.23e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 83: 3.2s to complete
#     error(train)=3.60e-01, acc(train)=8.74e-01, error(valid)=4.26e-01, acc(valid)=8.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 84: 3.2s to complete
#     error(train)=3.73e-01, acc(train)=8.70e-01, error(valid)=4.38e-01, acc(valid)=8.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 85: 3.3s to complete
#     error(train)=3.75e-01, acc(train)=8.68e-01, error(valid)=4.39e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 86: 3.3s to complete
#     error(train)=3.61e-01, acc(train)=8.74e-01, error(valid)=4.25e-01, acc(valid)=8.56e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 87: 3.4s to complete
#     error(train)=3.61e-01, acc(train)=8.74e-01, error(valid)=4.28e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 88: 3.3s to complete
#     error(train)=3.65e-01, acc(train)=8.71e-01, error(valid)=4.31e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 89: 3.3s to complete
#     error(train)=3.72e-01, acc(train)=8.71e-01, error(valid)=4.35e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 90: 3.4s to complete
#     error(train)=3.73e-01, acc(train)=8.69e-01, error(valid)=4.39e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 91: 3.3s to complete
#     error(train)=3.65e-01, acc(train)=8.73e-01, error(valid)=4.28e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 92: 3.2s to complete
#     error(train)=3.64e-01, acc(train)=8.75e-01, error(valid)=4.34e-01, acc(valid)=8.51e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 93: 3.4s to complete
#     error(train)=3.82e-01, acc(train)=8.68e-01, error(valid)=4.45e-01, acc(valid)=8.49e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 94: 3.6s to complete
#     error(train)=3.68e-01, acc(train)=8.71e-01, error(valid)=4.33e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 95: 3.3s to complete
#     error(train)=3.67e-01, acc(train)=8.71e-01, error(valid)=4.27e-01, acc(valid)=8.54e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 96: 3.5s to complete
#     error(train)=3.65e-01, acc(train)=8.74e-01, error(valid)=4.31e-01, acc(valid)=8.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 97: 3.3s to complete
#     error(train)=3.61e-01, acc(train)=8.76e-01, error(valid)=4.24e-01, acc(valid)=8.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 98: 3.7s to complete
#     error(train)=3.73e-01, acc(train)=8.72e-01, error(valid)=4.35e-01, acc(valid)=8.53e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 99: 3.6s to complete
#     error(train)=3.66e-01, acc(train)=8.74e-01, error(valid)=4.34e-01, acc(valid)=8.52e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 100: 3.3s to complete
#     error(train)=3.71e-01, acc(train)=8.71e-01, error(valid)=4.34e-01, acc(valid)=8.54e-01

# %%
print_stats(1,statss,keyss)
# Out:
# Val acc: 0.853987341772152, Train Error: 0.37107221059138834, Val Error: 0.43424534042188867

# %%
# Regularization Graphing

# Plot Dropout
dropout_vals = [0.6,0.7,0.85,0.97]
dropout_accs = [0.807,0.827,0.851,0.854]
dropout_gaps = [0.004,0.336,0.105,0.213]

fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)

ax_1.set_xlabel('Dropout value')
ax_1.set_ylabel('Accuracy')
ax_1.set_ylim([0, 1.0])
ax_1.plot(dropout_vals, dropout_accs, color='r',label = 'Val. Acc.')
ax_1.tick_params(axis='y')

ax_2 = ax_1.twinx()

ax_2.set_ylabel('Generalization gap')
ax_2.set_ylim([0, 1.0])
ax_2.plot(dropout_vals, dropout_gaps, color='b',label = 'Gap')
ax_2.tick_params(axis='y')

ax_1.legend(loc=0)
ax_2.legend(loc=2)

ax_1.grid('on')
ax_1.grid('off')
fig_1.tight_layout()
fig_1.savefig('dropout_plot.pdf')

# %%
# Plot L1 + L2

L_vals = [5e-4,1e-3,5e-3,5e-2]
L1_accs = [0.795,0.763,0.0241,0.022]
L1_gaps = [0.016,0.021,0.,0.]
L2_accs = [0.851,0.854,0.813,0.392]
L2_gaps = [0.154,0.063,0.021,0.002]

fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)

ax_1.set_xlabel('Dropout value')
ax_1.set_ylabel('Accuracy')
ax_1.set_ylim([0, 1.0])
ax_1.plot(L_vals, L1_accs, color='r',label = 'L1 Val. Acc.')
ax_1.plot(L_vals, L2_accs, color='b',label = 'L2 Val. Acc.')
ax_1.tick_params(axis='y')

ax_2 = ax_1.twinx()

ax_2.set_ylabel('Generalization gap')
ax_2.set_ylim([-0.1, 1.0])
ax_2.plot(L_vals, L1_gaps, color='r',label = 'L1 Gap',linestyle='dashed')
ax_2.plot(L_vals, L2_gaps, color='b',label = 'L2 Gap',linestyle='dashed')
ax_2.tick_params(axis='y')

ax_2.set_xscale('log')
ax_2.set_xlim([4e-4, 6e-2])

ax_1.legend(loc=0)
ax_2.legend(loc=2)

ax_1.grid('on')
fig_1.tight_layout()
fig_1.savefig('L_plot.pdf')
